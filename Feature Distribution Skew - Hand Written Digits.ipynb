# %%
import glob
import pandas as pd
from collections import defaultdict as ddict
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.set_style("whitegrid")

# %%
files = glob.glob('../hand_written_digits/*')

# %%
files
# Out:
# ['../hand_written_digits/mfeat-mor',
#  '../hand_written_digits/mfeat-kar',
#  '../hand_written_digits/mfeat-fou',
#  '../hand_written_digits/mfeat-fac',
#  '../hand_written_digits/mfeat-pix',
#  '../hand_written_digits/mfeat-zer']

# %%
data = [list(map(float, i.split())) for i in open(files[4],'r').readlines()]

# %%
len(data[0])
# Out:
# 240

# %%
DF = ddict(list)
for i in data:
    DF['avg'].append(sum(i)/240)
DF = pd.DataFrame(DF)

# %%
DF
# Out:
#            avg
# 0     3.408333
# 1     3.137500
# 2     3.279167
# 3     3.425000
# 4     2.995833
# ...        ...
# 1995  2.950000
# 1996  2.916667
# 1997  2.508333
# 1998  3.320833
# 1999  2.416667
#
# [2000 rows x 1 columns]

# %%
DF.iloc[0:200].avg.plot.kde()

plt.show()

# %%
DF.iloc[200:400].avg.plot.kde()
plt.show()

# %%
DF.iloc[400:600].avg.plot.kde()
plt.show()

# %%
DF.iloc[600:800].avg.plot.kde()
plt.show()

# %%
DF.iloc[800:1000].avg.plot.kde()
plt.show()

# %%
DF.iloc[1000:1200].avg.plot.kde()
plt.show()

# %%
DF.iloc[1200:1400].avg.plot.kde()
plt.show()

# %%
DF.iloc[1400:1600].avg.plot.kde()
plt.show()

# %%
DF.iloc[1600:1800].avg.plot.kde()
plt.show()

# %%
DF.iloc[1800:2000].avg.plot.kde()
plt.show()
