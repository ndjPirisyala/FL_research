# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
IID = pd.DataFrame({
    'Feature':[1,1,1,1,1,1,1,1,1],
    'Label':[1,0,0,0,0,0,1,1,1]
})

# %%
IID
# Out:
#    Feature  Label
# 0        1      1
# 1        1      0
# 2        1      0
# 3        1      0
# 4        1      0
# 5        1      0
# 6        1      1
# 7        1      1
# 8        1      1

# %%
IID.iloc[0:2]
# Out:
#    Feature  Label
# 0        1      1
# 1        1      0

# %%
IID.iloc[2:4]
# Out:
#    Feature  Label
# 2        1      0
# 3        1      0

# %%
NONIID = pd.DataFrame({
    'Feature':[1,2,3,4,3,6,5,1,1],
    'Label':[1,0,0,0,0,0,1,1,1]
})

# %%
NONIID
# Out:
#    Feature  Label
# 0        1      1
# 1        2      0
# 2        3      0
# 3        4      0
# 4        3      0
# 5        6      0
# 6        5      1
# 7        1      1
# 8        1      1

# %%
IID.loc[IID.Label==0].Feature.plot.kde()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-6-013e344f44ea> in <module>
# ----> 1 IID.loc[IID.Label==0].Feature.plot.kde()
#       2 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1286             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1287         """
# -> 1288         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1289
#    1290     density = kde
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...

# %%
NONIID.loc[NONIID.Label==0].Feature.plot.kde()
plt.show()

# %%
import glob
files = glob.glob('../hand_written_digits/*')

# %%
files
# Out:
# ['../hand_written_digits/mfeat-mor',
#  '../hand_written_digits/mfeat-kar',
#  '../hand_written_digits/mfeat-fou',
#  '../hand_written_digits/mfeat-fac',
#  '../hand_written_digits/mfeat-pix',
#  '../hand_written_digits/mfeat-zer']

# %%
files[2]
# Out:
# '../hand_written_digits/mfeat-fou'

# %%
len(open(files[2],'r').readlines())
# Out:
# 2000

# %%
len(open(files[0],'r').readlines()[0].split())
# Out:
# 6

# %%
open(files[0],'r').readlines()
# Out:
# ['     1.00000000     0.00000000     0.00000000   133.15086140     1.31169276  1620.22177892\n',
#  '     1.00000000     0.00000000     0.00000000   126.72486140     1.30274497  1609.33482208\n',
#  '     1.00000000     0.00000000     0.00000000   131.17386140     1.31903101  1568.97843469\n',
#  '     1.00000000     0.00000000     0.00000000   129.47886140     1.27087816  1695.05528143\n',
#  '     1.00000000     0.00000000     0.00000000   127.26286140     1.32963668  1647.72023493\n',
#  '     1.00000000     0.00000000     0.00000000   131.05886140     1.31040314  2027.21136662\n',
#  '     1.00000000     0.00000000     0.00000000   138.44286140     1.37990560  1918.75047185\n',
#  '     1.00000000     0.00000000     0.00000000   129.34686140     1.30564601  1547.26372726\n',
#  '     1.00000000     0.00000000     0.00000000   139.54286140     1.37466149  1871.05593439\n',
#  '     1.00000000     0.00000000     0.00000000   132.62886140     1.37443436  1884.68045797\n',
# ...
