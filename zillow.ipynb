# %%
# !ls -a -l ./zillow
# Out:
# total 1334892
# drwxr-xr-x  2 dns_cluster_2_gmail_com 1147768397      4096 Nov  6 09:38 .
# drwxr-xr-x 15 dns_cluster_2_gmail_com 1147768397      4096 Nov  6 09:40 ..
# -rw-r--r--  1 root                    root       648820905 Dec 11  2019 properties_2016.csv
# -rw-r--r--  1 root                    root       650093621 Dec 11  2019 properties_2017.csv
# -rw-r--r--  1 root                    root        62696830 Dec 11  2019 sample_submission.csv
# -rw-r--r--  1 root                    root         2452454 Dec 11  2019 train_2016_v2.csv
# -rw-r--r--  1 root                    root         2822022 Dec 11  2019 train_2017.csv
# -rw-r--r--  1 root                    root           19229 Dec 11  2019 zillow_data_dictionary.xlsx

# %%
import pandas as pd

# %%
df = pd.read_csv('./zillow/properties_2017.csv')
# Out:
# /home/dns_cluster_2_gmail_com/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (49) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  5.0                    NaN
# 3          0.0         0.0                  3.0                    6.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# ...

# %%
df2 = pd.read_csv('./zillow/train_2017.csv')

# %%
df2.head()
# Out:
#    parcelid  logerror transactiondate
# 0  14297519  0.025595      2017-01-01
# 1  17052889  0.055619      2017-01-01
# 2  14186244  0.005383      2017-01-01
# 3  12177905 -0.103410      2017-01-01
# 4  10887214  0.006940      2017-01-01

# %%
df.notnull().sum()
# Out:
# parcelid                        2985217
# airconditioningtypeid            815362
# architecturalstyletypeid           6061
# basementsqft                       1627
# bathroomcnt                     2982260
# bedroomcnt                      2982272
# buildingclasstypeid               12731
# buildingqualitytypeid           1941395
# calculatedbathnbr               2868061
# decktypeid                        17379
# finishedfloor1squarefeet         203758
# calculatedfinishedsquarefeet    2940120
# finishedsquarefeet12            2720786
# finishedsquarefeet13               7671
# finishedsquarefeet15             190185
# finishedsquarefeet50             203758
# finishedsquarefeet6               21482
# fips                            2982285
# fireplacecnt                     313124
# fullbathcnt                     2868061
# garagecarcnt                     891008
# garagetotalsqft                  891008
# hashottuborspa                    50062
# ...

# %%
df[df.notnull().any(axis=1)].shape
# Out:
# (2985217, 58)

# %%
df[df.isnull().any(axis=1)].shape
# Out:
# (2985217, 58)

# %%
df.shape
# Out:
# (2985217, 58)

# %%
df.isnull()
# Out:
#          parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0           False                   True                      True
# 1           False                   True                      True
# 2           False                   True                      True
# 3           False                   True                      True
# 4           False                   True                      True
# ...           ...                    ...                       ...
# 2985212     False                   True                      True
# 2985213     False                   True                      True
# 2985214     False                   True                      True
# 2985215     False                   True                      True
# 2985216     False                   True                      True
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0                True        False       False                 True
# ...

# %%
df1 = df.dropna()

# %%
print(df1)
# Out:
# Empty DataFrame
# ...

# %%
df1.size
# Out:
# 0

# %%
df2 = pd.read_csv("kc_house_data.csv")

# %%
df2
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
len(df2.zipcode.unique())
# Out:
# 70

# %%
for i in df2.zipcode.unique():
    print(i, df2.loc[df2.zipcode==i].shape[0])
# Out:
# 98178 262
# 98125 410
# 98028 283
# 98136 263
# 98074 441
# 98053 405
# 98003 280
# 98198 280
# 98146 288
# 98038 590
# 98007 141
# 98115 583
# 98107 266
# 98126 354
# 98019 190
# 98103 602
# 98002 199
# 98133 494
# 98040 282
# 98092 351
# 98030 256
# 98119 184
# 98112 269
# 98052 574
# 98027 412
# 98117 553
# 98058 455
# 98001 362
# 98056 406
# 98166 254
# 98023 499
# 98070 118
# 98148 57
# 98105 229
# 98042 548
# 98008 283
# 98059 468
# 98122 290
# 98144 343
# 98004 317
# 98005 168
# 98034 545
# 98075 359
# 98116 330
# 98010 100
# 98118 508
# 98199 317
# 98032 125
# 98045 221
# 98102 105
# 98077 198
# 98108 186
# 98168 269
# 98177 255
# 98065 310
# 98029 321
# 98006 498
# 98109 109
# 98022 234
# 98033 432
# 98155 446
# 98024 81
# 98011 195
# 98031 274
# 98106 335
# 98072 273
# 98188 136
# 98014 124
# 98055 268
# 98039 50
