# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.set_style("whitegrid")

# %%
df = pd.read_csv("kc_house_data.csv")

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
len(df.zipcode.unique())
# Out:
# 70

# %%
for i in df.zipcode.unique():
    print(i, df.loc[df.zipcode==i].shape[0])
# Out:
# 98178 262
# 98125 410
# 98028 283
# 98136 263
# 98074 441
# 98053 405
# 98003 280
# 98198 280
# 98146 288
# 98038 590
# 98007 141
# 98115 583
# 98107 266
# 98126 354
# 98019 190
# 98103 602
# 98002 199
# 98133 494
# 98040 282
# 98092 351
# 98030 256
# 98119 184
# 98112 269
# 98052 574
# 98027 412
# 98117 553
# 98058 455
# 98001 362
# 98056 406
# 98166 254
# 98023 499
# 98070 118
# 98148 57
# 98105 229
# 98042 548
# 98008 283
# 98059 468
# 98122 290
# 98144 343
# 98004 317
# 98005 168
# 98034 545
# 98075 359
# 98116 330
# 98010 100
# 98118 508
# 98199 317
# 98032 125
# 98045 221
# 98102 105
# 98077 198
# 98108 186
# 98168 269
# 98177 255
# 98065 310
# 98029 321
# 98006 498
# 98109 109
# 98022 234
# 98033 432
# 98155 446
# 98024 81
# 98011 195
# 98031 274
# 98106 335
# 98072 273
# 98188 136
# 98014 124
# 98055 268
# 98039 50

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.price.plot.kde()
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
zipcodes = df.zipcode.unique()
zipcodes
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039])

# %%
len(zipcodes)
# Out:
# 70

# %%
grouped = df.groupby(df.zipcode)

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

# for i in df.groupby(df.zipcode):
#     print(i[1])
#     x = df.columns[2]
#     i[1].price.plot.kde()
# plt.show()

for zc in zipcodes:
    data = grouped.get_group(zc).price/len(grouped.get_group(zc))
    data.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).bedrooms.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).bathrooms.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).sqft_living.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).sqft_lot.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).floors.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).waterfront.plot.kde()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-54-3b001c34c1b3> in <module>
#       2
#       3 for zc in zipcodes:
# ----> 4     grouped.get_group(zc).waterfront.plot.kde()
#       5 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1286             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1287         """
# -> 1288         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1289
#    1290     density = kde
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ...

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).view.plot.kde()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-55-63aa1b190622> in <module>
#       2
#       3 for zc in zipcodes:
# ----> 4     grouped.get_group(zc).view.plot.kde()
#       5 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1286             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1287         """
# -> 1288         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1289
#    1290     density = kde
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).condition.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).grade.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).sqft_above.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).sqft_basement.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
legend =[]
for zc in zipcodes:
    grouped.get_group(zc).yr_built.plot.kde()
    legend.append(zc)
plt.legend(legend) 
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).yr_renovated.plot.kde()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-62-5dc871dafd7c> in <module>
#       2
#       3 for zc in zipcodes:
# ----> 4     grouped.get_group(zc).yr_renovated.plot.kde()
#       5 plt.show()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1286             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1287         """
# -> 1288         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1289
#    1290     density = kde
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ...

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).lat.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).long.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).sqft_living15.plot.kde()
plt.show()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

for zc in zipcodes:
    grouped.get_group(zc).sqft_lot15.plot.kde()
plt.show()
