# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
columns = ['age','gender','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']

# %%
df_cleveland = pd.read_csv('../Heart_Disease/processed.cleveland.data', delimiter = ',', names=columns , header=None)

# %%
df_hungarian = pd.read_csv('../Heart_Disease/processed.hungarian.data', delimiter = ',', names=columns , header=None)

# %%
df_switzerland = pd.read_csv('../Heart_Disease/processed.switzerland.data', delimiter = ',', names=columns , header=None)

# %%
df_cleveland.head(5)
# Out:
#     age  gender   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0     1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0     1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0     1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0     1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0     0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
df_hungarian.head(5)
# Out:
#    age  gender  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28       1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29       1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29       1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30       0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31       0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  num
# 0    ?    0
# 1    ?    0
# 2    ?    0
# 3    6    0
# 4    ?    0

# %%
df_switzerland.head(5)
# Out:
#    age  gender  cp trestbps  chol fbs restecg thalach exang oldpeak slope ca  \
# 0   32       1   1       95     0   ?       0     127     0      .7     1  ?
# 1   34       1   4      115     0   ?       ?     154     0      .2     1  ?
# 2   35       1   4        ?     0   ?       0     130     1       ?     ?  ?
# 3   36       1   4      110     0   ?       0     125     1       1     2  ?
# 4   38       0   4      105     0   ?       0     166     0     2.8     1  ?
#
#   thal  num
# 0    ?    1
# 1    ?    1
# 2    7    3
# 3    6    1
# 4    ?    2

# %%
df_cleveland.hist('num')
plt.show()

# %%
df_hungarian.hist('num')
plt.show()

# %%
df_switzerland.hist('num')
plt.show()
