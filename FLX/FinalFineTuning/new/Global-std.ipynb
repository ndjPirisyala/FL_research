# %% [markdown]
# ### Normal DeepLearning

# %%
# !rm -rf Local-one*
# !rm -rf Local-two*
# !rm -rf TEST
# !rm -rf TESTV-*
# !rm *.pkl
# !rm [0-9].csv
# Out:
# rm: cannot remove '[0-9].csv': No such file or directory

# %%
import pandas as pd
import os
import pickle
# os.system('rm -rf Local-one*')
# os.system('rm -rf Local-two*')
# os.system('rm -rf TEST')
# os.system('rm -rf TEST-*')

# %%
train = pd.read_csv('tra.csv')
test  = pd.read_csv('TEST.csv')

train.drop(train.filter(regex="Unname"),axis=1, inplace=True)
test.drop(test.filter(regex="Unname"),axis=1, inplace=True)

# %%
train.head()
# Out:
#    Input1  Input2  Input3  Input4  Input5  Input6  Input7  Input8  Input9  \
# 0      47     100      27      81      57      37      26       0       0
# 1       0      89      27     100      42      75      29      45      15
# 2       0      57      31      68      72      90     100     100      76
# 3       0     100       7      92       5      68      19      45      86
# 4       0      67      49      83     100     100      81      80      60
#
#    Input10  Input11  Input12  Input13  Input14  Input15  Input16  digit  \
# 0       23       56       53      100       90       40       98      8
# 1       15       37        0       69        2      100        6      2
# 2       75       50       51       28       25       16        0      1
# 3       34      100       45       74       23       67        0      4
# 4       60       40       40       33       20       47        0      1
#
#    writer
# 0      12
# 1      26
# 2      11
# 3      14
# 4      10

# %%
test.head()
# Out:
#    Input1  Input2  Input3  Input4  Input5  Input6  Input7  Input8  Input9  \
# 0      88      92       2      99      16      66      94      37      70
# 1      80     100      18      98      60      66     100      29      42
# 2       0      94       9      57      20      19       7       0      20
# 3      95      82      71     100      27      77      77      73     100
# 4      68     100       6      88      47      75      87      82      85
#
#    Input10  Input11  Input12  Input13  Input14  Input15  Input16  digit
# 0        0        0       24       42       65      100      100      8
# 1        0        0       23       42       61       56       98      8
# 2       36       70       68      100      100       18       92      8
# 3       80       93       42       56       13        0        0      9
# 4       56      100       29       75        6        0        0      9

# %%
train.iloc[:,:-1].describe()
# Out:
#             Input1       Input2       Input3       Input4       Input5  \
# count  7494.000000  7494.000000  7494.000000  7494.000000  7494.000000
# mean     37.384307    84.679343    40.005604    82.889512    50.878303
# std      33.322024    16.848420    26.256025    19.638582    34.927201
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000    76.000000    20.000000    70.000000    17.000000
# 50%      31.000000    89.000000    39.000000    89.000000    56.000000
# 75%      61.000000   100.000000    58.000000   100.000000    81.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#             Input6       Input7       Input8       Input9      Input10  \
# count  7494.000000  7494.000000  7494.000000  7494.000000  7494.000000
# mean     65.044436    51.471844    44.599680    57.129971    34.069122
# std      27.377341    30.680075    30.659478    33.680340    27.459989
# ...

# %%
import seaborn as sns
sns.set_theme(style= 'whitegrid')

# %%
from  matplotlib import pyplot as plt

train.hist(figsize = (17.5,12))

plt.show()

# %%
test.iloc[:,:-1].describe()
# Out:
#             Input1       Input2       Input3       Input4       Input5  \
# count  3498.000000  3498.000000  3498.000000  3498.000000  3498.000000
# mean     41.877930    86.064894    41.891081    85.669525    47.396798
# std      35.995293    14.737085    26.486364    17.960876    32.134722
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       8.000000    77.000000    22.000000    75.000000    19.000000
# 50%      34.000000    90.000000    42.000000    94.000000    49.000000
# 75%      75.000000   100.000000    60.000000   100.000000    73.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#             Input6       Input7       Input8       Input9      Input10  \
# count  3498.000000  3498.000000  3498.000000  3498.000000  3498.000000
# mean     66.705832    50.681246    44.283305    56.308462    32.896512
# std      26.130413    30.351970    28.227548    35.089176    26.785929
# ...

# %%
from  matplotlib import pyplot as plt

test.hist(figsize = (17.5,12))

plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(train.iloc[:,:-2].corr(), annot = True ,linewidths=.05)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(test.iloc[:,:-1].corr(), annot = True ,linewidths=.05)
plt.show()

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(10,activation="sigmoid")
    ])

model.compile(optimizer='SGD',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
model.fit(train.iloc[:,:-2], train.digit, epochs=25, batch_size = 32)
# Out:
# Epoch 1/25
# 235/235 [==============================] - 1s 778us/step - loss: 2.9148 - accuracy: 0.6075
# Epoch 2/25
# 235/235 [==============================] - 0s 848us/step - loss: 0.3229 - accuracy: 0.9032
# Epoch 3/25
# 235/235 [==============================] - 0s 779us/step - loss: 0.2170 - accuracy: 0.9354
# Epoch 4/25
# 235/235 [==============================] - 0s 759us/step - loss: 0.1532 - accuracy: 0.9527
# Epoch 5/25
# 235/235 [==============================] - 0s 770us/step - loss: 0.1460 - accuracy: 0.9575
# Epoch 6/25
# 235/235 [==============================] - 0s 771us/step - loss: 0.1092 - accuracy: 0.9708
# Epoch 7/25
# 235/235 [==============================] - 0s 784us/step - loss: 0.1037 - accuracy: 0.9702
# Epoch 8/25
# 235/235 [==============================] - 0s 779us/step - loss: 0.0902 - accuracy: 0.9778
# Epoch 9/25
# 235/235 [==============================] - 0s 751us/step - loss: 0.0788 - accuracy: 0.9754
# Epoch 10/25
# ...

# %%
import numpy as np
import warnings
warnings.filterwarnings("ignore")


y_predict = model.predict_classes(test.iloc[:,:-1])
Y_predict = np.array(test.digit)

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_predict, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.94      0.74       363
#            1       0.48      0.95      0.64       364
#            2       0.95      0.99      0.97       364
#            3       0.80      0.56      0.66       336
#            4       0.90      0.77      0.83       364
#            5       0.64      0.79      0.71       335
#            6       0.92      0.42      0.58       336
#            7       0.96      0.91      0.93       364
#            8       0.92      0.53      0.67       336
#            9       0.96      0.55      0.70       336
#
#     accuracy                           0.75      3498
#    macro avg       0.81      0.74      0.74      3498
# weighted avg       0.81      0.75      0.75      3498

# %%
import scikitplot as skplt


skplt.metrics.plot_roc_curve(Y_predict,model.predict(test.iloc[:,:-1]), figsize = (8,8))
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                544
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# ...
# Total params: 1,146
# Trainable params: 1,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model.save('TEST')

# %% [markdown]
# ### FL

# %%
import os
os.system('python3 client-t1.py one 0')
os.system('python3 client-t1.py one 1')
os.system('python3 client-t1.py one 2')
os.system('python3 client-t1.py one 3')
os.system('python3 client-t1.py one 4')
os.system('python3 client-t1.py one 5')
os.system('python3 client-t1.py one 6')
os.system('python3 client-t1.py one 7')
os.system('python3 client-t1.py one 8')
os.system('python3 client-t1.py one 9')
# Out:
# 0

# %%
# import pickle
# c0=pickle.load(open('0.pkl','rb'))
# c1=pickle.load(open('1.pkl','rb'))
# c2=pickle.load(open('2.pkl','rb'))
# c3=pickle.load(open('3.pkl','rb'))
# c4=pickle.load(open('4.pkl','rb'))
# c5=pickle.load(open('5.pkl','rb'))
# c6=pickle.load(open('6.pkl','rb'))
# c7=pickle.load(open('7.pkl','rb'))
# c8=pickle.load(open('8.pkl','rb'))
# c9=pickle.load(open('9.pkl','rb'))

# Total = [c0,c1,c2,c3,c4,c5,c6,c7,c8,c9]

# L = list(map(lambda x: 1/pow(x,2),list(map(lambda x:x/sum(Total),Total))))
# L = list(map(lambda x:x/sum(L),L))

# %%
run = True

# %%
from tqdm import tqdm_notebook
R1=[]
R2=[]
for i in tqdm_notebook(range(30)):
    model0 = tf.keras.models.load_model('Local-one-0')
    model1 = tf.keras.models.load_model('Local-one-1')
    model2 = tf.keras.models.load_model('Local-one-2')
    model3 = tf.keras.models.load_model('Local-one-3')
    model4 = tf.keras.models.load_model('Local-one-4')
    model5 = tf.keras.models.load_model('Local-one-5')
    model6 = tf.keras.models.load_model('Local-one-6')
    model7 = tf.keras.models.load_model('Local-one-7')    
    model8 = tf.keras.models.load_model('Local-one-8')
    model9 = tf.keras.models.load_model('Local-one-9')

    w01,b01,w02,b02,w03,b03 = model0.get_weights()
    w11,b11,w12,b12,w13,b13 = model1.get_weights()
    w21,b21,w22,b22,w23,b23 = model2.get_weights()
    w31,b31,w32,b32,w33,b33 = model3.get_weights()
    w41,b41,w42,b42,w43,b43 = model4.get_weights()
    w51,b51,w52,b52,w53,b53 = model5.get_weights()
    w61,b61,w62,b62,w63,b63 = model6.get_weights()
    w71,b71,w72,b72,w73,b73 = model7.get_weights()
    w81,b81,w82,b82,w83,b83 = model8.get_weights()
    w91,b91,w92,b92,w93,b93 = model9.get_weights()

    os.system('rm -rf Local-one*')
    os.system('rm -rf TEST')

    w1 = np.array([w01,w11,w21,w31,w41,w51,w61,w71,w81,w91])
    w2 = np.array([w02,w12,w22,w32,w42,w52,w62,w72,w82,w92])
    w3 = np.array([w03,w13,w23,w33,w43,w53,w63,w73,w83,w93])

    b1 = np.array([b01,b11,b21,b31,b41,b51,b61,b71,b81,b91])
    b2 = np.array([b02,b12,b22,b32,b42,b52,b62,b72,b82,b92])
    b3 = np.array([b03,b13,b23,b33,b43,b53,b63,b73,b83,b93])

    W1 = w1.sum(axis=0)/10.0
    W2 = w2.sum(axis=0)/10.0
    W3 = w3.sum(axis=0)/10.0

    B1 = b1.sum(axis=0)/10.0
    B2 = b2.sum(axis=0)/10.0
    B3 = b3.sum(axis=0)/10.0

    model.set_weights([W1,B1,W2,B2,W3,B3])

#     y_predict = model.predict_classes(test.iloc[:,:-1])
#     Y_predict = np.array(test.digit)

#     print(classification_report(Y_predict, y_predict))


#     skplt.metrics.plot_roc_curve(Y_predict,model.predict(test.iloc[:,:-1]), figsize = (8,8))
#     plt.show()

    R1.append(model.evaluate(test.iloc[:,:-1], test.digit))
    
#     model.save('TEST-{}'.format(i))
    model.save('TEST')

    os.system('python3 client.py one 0')
    os.system('python3 client.py one 1')
    os.system('python3 client.py one 2')
    os.system('python3 client.py one 3')
    os.system('python3 client.py one 4')
    os.system('python3 client.py one 5')
    os.system('python3 client.py one 6')
    os.system('python3 client.py one 7')
    os.system('python3 client.py one 8')
    os.system('python3 client.py one 9')
    
    #-----------------------------------
    if run:
#         model.save('TEST2')
        os.system('python3 client-v2.py two 0')
        os.system('python3 client-v2.py two 1')
        os.system('python3 client-v2.py two 2')
        os.system('python3 client-v2.py two 3')
        os.system('python3 client-v2.py two 4')
        os.system('python3 client-v2.py two 5')
        os.system('python3 client-v2.py two 6')
        os.system('python3 client-v2.py two 7')
        os.system('python3 client-v2.py two 8')
        os.system('python3 client-v2.py two 9')
        run = False

    model0 = tf.keras.models.load_model('Local-two-0')
    model1 = tf.keras.models.load_model('Local-two-1')
    model2 = tf.keras.models.load_model('Local-two-2')
    model3 = tf.keras.models.load_model('Local-two-3')
    model4 = tf.keras.models.load_model('Local-two-4')
    model5 = tf.keras.models.load_model('Local-two-5')
    model6 = tf.keras.models.load_model('Local-two-6')
    model7 = tf.keras.models.load_model('Local-two-7')    
    model8 = tf.keras.models.load_model('Local-two-8')
    model9 = tf.keras.models.load_model('Local-two-9')
    
    c0=pickle.load(open('0.pkl','rb'))
    c1=pickle.load(open('1.pkl','rb'))
    c2=pickle.load(open('2.pkl','rb'))
    c3=pickle.load(open('3.pkl','rb'))
    c4=pickle.load(open('4.pkl','rb'))
    c5=pickle.load(open('5.pkl','rb'))
    c6=pickle.load(open('6.pkl','rb'))
    c7=pickle.load(open('7.pkl','rb'))
    c8=pickle.load(open('8.pkl','rb'))
    c9=pickle.load(open('9.pkl','rb'))

    Total = [c0,c1,c2,c3,c4,c5,c6,c7,c8,c9]
#     print([c0,c1,c2,c3,c4,c5,c6,c7,c8,c9])


    #previous
#    L = list(map(lambda x: 1/pow(x,2),list(map(lambda x:x/sum(Total),Total))))
    #now
    L = list(map(lambda x: 286.2864/x,list(map(lambda x:x/sum(Total),Total))))

    L = list(map(lambda x:x/sum(L),L))

    w01,b01,w02,b02,w03,b03 = model0.get_weights()
    w11,b11,w12,b12,w13,b13 = model1.get_weights()
    w21,b21,w22,b22,w23,b23 = model2.get_weights()
    w31,b31,w32,b32,w33,b33 = model3.get_weights()
    w41,b41,w42,b42,w43,b43 = model4.get_weights()
    w51,b51,w52,b52,w53,b53 = model5.get_weights()
    w61,b61,w62,b62,w63,b63 = model6.get_weights()
    w71,b71,w72,b72,w73,b73 = model7.get_weights()
    w81,b81,w82,b82,w83,b83 = model8.get_weights()
    w91,b91,w92,b92,w93,b93 = model9.get_weights()
    
    model0eval = model0.evaluate(test.iloc[:,:-1], test.digit,verbose=0)[-1]
    model1eval = model1.evaluate(test.iloc[:,:-1], test.digit,verbose=0)[-1]
    model2eval = model2.evaluate(test.iloc[:,:-1], test.digit,verbose=0)[-1]
    model3eval = model3.evaluate(test.iloc[:,:-1], test.digit,verbose=0)[-1]
    model4eval = model4.evaluate(test.iloc[:,:-1], test.digit,verbose=0)[-1]
    model5eval = model5.evaluate(test.iloc[:,:-1], test.digit,verbose=0)[-1]
    model6eval = model6.evaluate(test.iloc[:,:-1], test.digit,verbose=0)[-1]
    model7eval = model7.evaluate(test.iloc[:,:-1], test.digit,verbose=0)[-1]
    model8eval = model8.evaluate(test.iloc[:,:-1], test.digit,verbose=0)[-1]
    model9eval = model9.evaluate(test.iloc[:,:-1], test.digit,verbose=0)[-1]
    
    w01 = np.array(w01)*L[0]
    b01 = np.array(b01)*L[0]
    w02 = np.array(w02)*L[0]
    b02 = np.array(b02)*L[0]
    w03 = np.array(w03)*L[0]
    b03 = np.array(b03)*L[0]
    
    w11 = np.array(w11)*L[1]
    b11 = np.array(b11)*L[1]
    w12 = np.array(w12)*L[1]
    b12 = np.array(b12)*L[1]
    w13 = np.array(w13)*L[1]
    b13 = np.array(b13)*L[1]
    
    w21 = np.array(w21)*L[2]
    b21 = np.array(b21)*L[2]
    w22 = np.array(w22)*L[2]
    b22 = np.array(b22)*L[2]
    w23 = np.array(w23)*L[2]
    b23 = np.array(b23)*L[2]
    
    w31 = np.array(w31)*L[3]
    b31 = np.array(b31)*L[3]
    w32 = np.array(w32)*L[3]
    b32 = np.array(b32)*L[3]
    w33 = np.array(w33)*L[3]
    b33 = np.array(b33)*L[3]
    
    w41 = np.array(w41)*L[4]
    b41 = np.array(b41)*L[4]
    w42 = np.array(w42)*L[4]
    b42 = np.array(b42)*L[4]
    w43 = np.array(w43)*L[4]
    b43 = np.array(b43)*L[4]
    
    w51 = np.array(w51)*L[5]
    b51 = np.array(b51)*L[5]
    w52 = np.array(w52)*L[5]
    b52 = np.array(b52)*L[5]
    w53 = np.array(w53)*L[5]
    b53 = np.array(b53)*L[5]
    
    w61 = np.array(w61)*L[6]
    b61 = np.array(b61)*L[6]
    w62 = np.array(w62)*L[6]
    b62 = np.array(b62)*L[6]
    w63 = np.array(w63)*L[6]
    b63 = np.array(b63)*L[6]
    
    w71 = np.array(w71)*L[7]
    b71 = np.array(b71)*L[7]
    w72 = np.array(w72)*L[7]
    b72 = np.array(b72)*L[7]
    w73 = np.array(w73)*L[7]
    b73 = np.array(b73)*L[7]
    
    w81 = np.array(w81)*L[8]
    b81 = np.array(b81)*L[8]
    w82 = np.array(w82)*L[8]
    b82 = np.array(b82)*L[8]
    w83 = np.array(w83)*L[8]
    b83 = np.array(b83)*L[8]
    
    w91 = np.array(w91)*L[9]
    b91 = np.array(b91)*L[9]
    w92 = np.array(w92)*L[9]
    b92 = np.array(b92)*L[9]
    w93 = np.array(w93)*L[9]
    b93 = np.array(b93)*L[9]
    
         
    os.system('rm -rf Local-two*')
#     os.system('rm -rf TEST2')

    w1 = np.array([w01,w11,w21,w31,w41,w51,w61,w71,w81,w91])
    w2 = np.array([w02,w12,w22,w32,w42,w52,w62,w72,w82,w92])
    w3 = np.array([w03,w13,w23,w33,w43,w53,w63,w73,w83,w93])
    b1 = np.array([b01,b11,b21,b31,b41,b51,b61,b71,b81,b91])
    b2 = np.array([b02,b12,b22,b32,b42,b52,b62,b72,b82,b92])
    b3 = np.array([b03,b13,b23,b33,b43,b53,b63,b73,b83,b93])

    W1 = w1.sum(axis=0)
    W2 = w2.sum(axis=0)
    W3 = w3.sum(axis=0)

    B1 = b1.sum(axis=0)
    B2 = b2.sum(axis=0)
    B3 = b3.sum(axis=0)

    model.set_weights([W1,B1,W2,B2,W3,B3])

#     y_predict = model.predict_classes(test.iloc[:,:-1])
#     Y_predict = np.array(test.digit)

#     print(classification_report(Y_predict, y_predict))


#     skplt.metrics.plot_roc_curve(Y_predict,model.predict(test.iloc[:,:-1]), figsize = (8,8))
#     plt.show()

    R2.append(model.evaluate(test.iloc[:,:-1], test.digit))

    model.save('TEST2')
#     model.save('TEST-{}'.format(i))

#     os.system('python3 client-v2.py two 0 {}'.format(i))
#     os.system('python3 client-v2.py two 1 {}'.format(i))
#     os.system('python3 client-v2.py two 2 {}'.format(i))
#     os.system('python3 client-v2.py two 3 {}'.format(i))
#     os.system('python3 client-v2.py two 4 {}'.format(i))
#     os.system('python3 client-v2.py two 5 {}'.format(i))
#     os.system('python3 client-v2.py two 6 {}'.format(i))
#     os.system('python3 client-v2.py two 7 {}'.format(i))
#     os.system('python3 client-v2.py two 8 {}'.format(i))
#     os.system('python3 client-v2.py two 9 {}'.format(i))
    os.system('python3 client-v2.py two 0')
    os.system('python3 client-v2.py two 1')
    os.system('python3 client-v2.py two 2')
    os.system('python3 client-v2.py two 3')
    os.system('python3 client-v2.py two 4')
    os.system('python3 client-v2.py two 5')
    os.system('python3 client-v2.py two 6')
    os.system('python3 client-v2.py two 7')
    os.system('python3 client-v2.py two 8')
    os.system('python3 client-v2.py two 9')
# Out:
# ...
# 110/110 [==============================] - 0s 706us/step - loss: 2.3025 - accuracy: 0.1041
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 733us/step - loss: 1.2090 - accuracy: 0.5543
# INFO:tensorflow:Assets written to: TEST2/assets
# 110/110 [==============================] - 0s 800us/step - loss: 2.2220 - accuracy: 0.1872
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 708us/step - loss: 1.1070 - accuracy: 0.6306
# INFO:tensorflow:Assets written to: TEST2/assets
# 110/110 [==============================] - 0s 801us/step - loss: 3.1064 - accuracy: 0.1692
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 744us/step - loss: 1.0747 - accuracy: 0.5898
# INFO:tensorflow:Assets written to: TEST2/assets
# 110/110 [==============================] - 0s 616us/step - loss: 3.2339 - accuracy: 0.1878
# INFO:tensorflow:Assets written to: TEST/assets
# ...

# %%
import seaborn as sns
sns.set_theme(style= 'whitegrid')

plt.figure(figsize=(8,6))
plt.plot(list(map(lambda x:x[1],R1)),label="accuracy std")
plt.plot(list(map(lambda x:x[1],R2)),label="accuracy cus")
plt.ylabel("accuracy")
plt.xlabel("round")
plt.legend(loc="lower right")
plt.show()

# %%
from scipy import interpolate
RANGE = range(1,31)
plt.figure(figsize=(8,6))
plt.plot(range(1,31),interpolate.UnivariateSpline(RANGE, list(map(lambda x:x[1],R1)))(RANGE), label="accuracy std")
plt.plot(range(1,31),interpolate.UnivariateSpline(RANGE, list(map(lambda x:x[1],R2)))(RANGE), label="accuracy cus")
plt.ylabel("accuracy")
plt.xlabel("round")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(list(map(lambda x:x[0],R1)),label='loss std')
plt.plot(list(map(lambda x:x[0],R2)),label='loss cus')
plt.ylabel("loss")
plt.xlabel("round")
plt.legend()
plt.show()

# %% [markdown]
# ### Plot

# %%
from scipy import interpolate
RANGE = range(1,31)
plt.figure(figsize=(8,6))
plt.plot(range(1,31),interpolate.UnivariateSpline(RANGE, list(map(lambda x:x[0],R1)))(RANGE), label="loss std")
plt.plot(range(1,31),interpolate.UnivariateSpline(RANGE, list(map(lambda x:x[0],R2)))(RANGE), label="loss cus")
plt.ylabel("accuracy")
plt.xlabel("round")
plt.legend()
plt.show()
