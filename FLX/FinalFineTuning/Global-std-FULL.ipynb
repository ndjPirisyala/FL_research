# %% [markdown]
# ### Normal DeepLearning

# %%
# !rm -rf Local-one*
# !rm -rf Local-two*
# !rm -rf TEST
# !rm -rf TEST-*
# !rm -rf TESTV-*

# %%
import pandas as pd
import os
# os.system('rm -rf Local-one*')
# os.system('rm -rf Local-two*')
# os.system('rm -rf TEST')
# os.system('rm -rf TEST-*')

# %%
train = pd.read_csv('tra.csv').sample(n=1000, random_state=1)
test  = pd.read_csv('TEST.csv')

train.drop(train.filter(regex="Unname"),axis=1, inplace=True)
test.drop(test.filter(regex="Unname"),axis=1, inplace=True)

# %%
train.shape
# Out:
# (1000, 18)

# %%
train.head()
# Out:
#       Input1  Input2  Input3  Input4  Input5  Input6  Input7  Input8  Input9  \
# 5344      60      86      55      71       0      71      42      97     100
# 2641      75     100      32      76       9      50       0      22      37
# 1381      74     100      50      99      13      67       0      31      35
# 3474      30     100      33      81       4      54       0      29      70
# 186       79      74      21      67      15      92      71     100     100
#
#       Input10  Input11  Input12  Input13  Input14  Input15  Input16  digit  \
# 5344      100       96       64       62       31       38        0      9
# 2641        0      100       15       89       40       39       22      6
# 1381        0      100       10       79       43       10       52      6
# 3474       27      100       49       94       29       98        0      4
# 186        75       73       45       36       18        0        0      9
#
#       writer
# 5344       6
# 2641       9
# 1381      23
# 3474      23
# 186       27

# %%
test.head()
# Out:
#    Input1  Input2  Input3  Input4  Input5  Input6  Input7  Input8  Input9  \
# 0      88      92       2      99      16      66      94      37      70
# 1      80     100      18      98      60      66     100      29      42
# 2       0      94       9      57      20      19       7       0      20
# 3      95      82      71     100      27      77      77      73     100
# 4      68     100       6      88      47      75      87      82      85
#
#    Input10  Input11  Input12  Input13  Input14  Input15  Input16  digit
# 0        0        0       24       42       65      100      100      8
# 1        0        0       23       42       61       56       98      8
# 2       36       70       68      100      100       18       92      8
# 3       80       93       42       56       13        0        0      9
# 4       56      100       29       75        6        0        0      9

# %%
train.iloc[:,:-1].describe()
# Out:
#             Input1       Input2       Input3       Input4       Input5  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     38.540000    85.137000    40.486000    83.946000    50.360000
# std      33.622714    16.304848    25.867256    18.566254    34.873752
# min       0.000000     0.000000     0.000000     2.000000     0.000000
# 25%       6.000000    76.000000    22.000000    72.000000    15.000000
# 50%      33.000000    90.000000    40.000000    91.000000    56.000000
# 75%      64.000000   100.000000    57.000000   100.000000    80.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#             Input6       Input7       Input8      Input9      Input10  \
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean     66.915000    51.123000    46.317000    57.43600    33.604000
# std      26.359792    31.132091    30.059243    32.92315    27.636298
# min       0.000000     0.000000     0.000000     0.00000     0.000000
# 25%      51.000000    27.000000    27.000000    31.00000     7.000000
# 50%      72.000000    54.000000    44.000000    60.00000    32.000000
# 75%      87.000000    75.000000    66.000000    88.00000    54.000000
# max     100.000000   100.000000   100.000000   100.00000   100.000000
#
#            Input11      Input12      Input13      Input14      Input15  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     61.528000    33.286000    54.382000    33.482000    46.642000
# std      36.878737    26.696271    22.502054    31.593953    41.558597
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      26.000000    10.000000    41.000000     6.000000     0.000000
# 50%      74.000000    29.000000    52.500000    27.000000    39.000000
# 75%      97.250000    53.000000    68.000000    43.000000   100.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#            Input16        digit
# count  1000.000000  1000.000000
# mean     26.951000     4.473000
# std      34.903536     2.857523
# min       0.000000     0.000000
# 25%       0.000000     2.000000
# 50%       7.000000     4.000000
# 75%      45.250000     7.000000
# max     100.000000     9.000000

# %%
import seaborn as sns
sns.set_theme(style= 'whitegrid')

# %%
from  matplotlib import pyplot as plt

train.hist(figsize = (17.5,12))

plt.show()

# %%
test.iloc[:,:-1].describe()
# Out:
#             Input1       Input2       Input3       Input4       Input5  \
# count  3498.000000  3498.000000  3498.000000  3498.000000  3498.000000
# mean     41.877930    86.064894    41.891081    85.669525    47.396798
# std      35.995293    14.737085    26.486364    17.960876    32.134722
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       8.000000    77.000000    22.000000    75.000000    19.000000
# 50%      34.000000    90.000000    42.000000    94.000000    49.000000
# 75%      75.000000   100.000000    60.000000   100.000000    73.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#             Input6       Input7       Input8       Input9      Input10  \
# count  3498.000000  3498.000000  3498.000000  3498.000000  3498.000000
# mean     66.705832    50.681246    44.283305    56.308462    32.896512
# std      26.130413    30.351970    28.227548    35.089176    26.785929
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      52.000000    29.000000    26.000000    26.000000     6.000000
# 50%      71.000000    52.000000    44.000000    59.000000    32.000000
# 75%      87.000000    73.000000    63.000000    91.000000    52.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#            Input11      Input12      Input13      Input14      Input15  \
# count  3498.000000  3498.000000  3498.000000  3498.000000  3498.000000
# mean     58.586049    32.779302    55.713265    33.086621    48.302459
# std      37.555535    26.183399    21.745726    32.937557    42.234080
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      21.000000    11.000000    43.000000     4.000000     0.000000
# 50%      70.000000    28.000000    53.000000    25.000000    42.000000
# 75%      94.000000    52.000000    68.000000    47.000000   100.000000
# max     100.000000   100.000000   100.000000   100.000000   100.000000
#
#            Input16
# count  3498.000000
# mean     29.445111
# std      35.705016
# min       0.000000
# 25%       0.000000
# 50%      12.000000
# 75%      51.000000
# max     100.000000

# %%
from  matplotlib import pyplot as plt

test.hist(figsize = (17.5,12))

plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(train.iloc[:,:-2].corr(), annot = True ,linewidths=.05)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(test.iloc[:,:-1].corr(), annot = True ,linewidths=.05)
plt.show()

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(10,activation="sigmoid")
    ])

model.compile(optimizer='SGD',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %%
model.fit(train.iloc[:,:-2], train.digit, epochs=25, batch_size = 32)
# Out:
# Epoch 1/25
# 32/32 [==============================] - 0s 1ms/step - loss: 7.4116 - accuracy: 0.2294
# Epoch 2/25
# 32/32 [==============================] - 0s 1ms/step - loss: 1.5432 - accuracy: 0.5103
# Epoch 3/25
# 32/32 [==============================] - 0s 1ms/step - loss: 1.3721 - accuracy: 0.6006
# Epoch 4/25
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1081 - accuracy: 0.6298
# Epoch 5/25
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1259 - accuracy: 0.6333
# Epoch 6/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9270 - accuracy: 0.7054
# Epoch 7/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9032 - accuracy: 0.7100
# Epoch 8/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8295 - accuracy: 0.7459
# Epoch 9/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7313 - accuracy: 0.8004
# Epoch 10/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6383 - accuracy: 0.7968
# Epoch 11/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7373 - accuracy: 0.7740
# Epoch 12/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5585 - accuracy: 0.8411
# Epoch 13/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4119 - accuracy: 0.8802
# Epoch 14/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4195 - accuracy: 0.8600
# Epoch 15/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3798 - accuracy: 0.8858
# Epoch 16/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3248 - accuracy: 0.9084
# Epoch 17/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3438 - accuracy: 0.8937
# Epoch 18/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2283 - accuracy: 0.9108
# Epoch 19/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2673 - accuracy: 0.9206
# Epoch 20/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1871 - accuracy: 0.9336
# Epoch 21/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5568 - accuracy: 0.8730
# Epoch 22/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2010 - accuracy: 0.9224
# Epoch 23/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1722 - accuracy: 0.9458
# Epoch 24/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2667 - accuracy: 0.9103
# Epoch 25/25
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1664 - accuracy: 0.9514

# %%
import numpy as np
import warnings
warnings.filterwarnings("ignore")


y_predict = model.predict_classes(test.iloc[:,:-1])
Y_predict = np.array(test.digit)

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_predict, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       363
#            1       0.69      0.63      0.66       364
#            2       0.84      0.83      0.83       364
#            3       0.95      0.91      0.93       336
#            4       0.98      0.88      0.93       364
#            5       0.74      0.79      0.76       335
#            6       0.98      0.95      0.96       336
#            7       0.93      0.85      0.89       364
#            8       0.88      0.90      0.89       336
#            9       0.74      0.95      0.83       336
#
#     accuracy                           0.86      3498
#    macro avg       0.87      0.86      0.86      3498
# weighted avg       0.87      0.86      0.86      3498

# %%
import scikitplot as skplt


skplt.metrics.plot_roc_curve(Y_predict,model.predict(test.iloc[:,:-1]), figsize = (8,8))
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                544
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 1,146
# Trainable params: 1,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('TEST')
# Out:
# INFO:tensorflow:Assets written to: TEST/assets

# %% [markdown]
# ### FL

# %%
import os

os.system('python3 client.py one 0')
os.system('python3 client.py one 1')
os.system('python3 client.py one 2')
os.system('python3 client.py one 3')
os.system('python3 client.py one 4')
os.system('python3 client.py one 5')
os.system('python3 client.py one 6')
os.system('python3 client.py one 7')
os.system('python3 client.py one 8')
os.system('python3 client.py one 9')
# Out:
# 0

# %%
from tqdm import tqdm_notebook
R=[]
for i in tqdm_notebook(range(30)):
    model0 = tf.keras.models.load_model('Local-one-0')
    model1 = tf.keras.models.load_model('Local-one-1')
    model2 = tf.keras.models.load_model('Local-one-2')
    model3 = tf.keras.models.load_model('Local-one-3')
    model4 = tf.keras.models.load_model('Local-one-4')
    model5 = tf.keras.models.load_model('Local-one-5')
    model6 = tf.keras.models.load_model('Local-one-6')
    model7 = tf.keras.models.load_model('Local-one-7')    
    model8 = tf.keras.models.load_model('Local-one-8')
    model9 = tf.keras.models.load_model('Local-one-9')

    w01,b01,w02,b02,w03,b03 = model0.get_weights()
    w11,b11,w12,b12,w13,b13 = model1.get_weights()
    w21,b21,w22,b22,w23,b23 = model2.get_weights()
    w31,b31,w32,b32,w33,b33 = model3.get_weights()
    w41,b41,w42,b42,w43,b43 = model4.get_weights()
    w51,b51,w52,b52,w53,b53 = model5.get_weights()
    w61,b61,w62,b62,w63,b63 = model6.get_weights()
    w71,b71,w72,b72,w73,b73 = model7.get_weights()
    w81,b81,w82,b82,w83,b83 = model8.get_weights()
    w91,b91,w92,b92,w93,b93 = model9.get_weights()

    os.system('rm -rf Local-one*')
    os.system('rm -rf TEST')

    w1 = np.array([w01,w11,w21,w31,w41,w51,w61,w71,w81,w91])
    w2 = np.array([w02,w12,w22,w32,w42,w52,w62,w72,w82,w92])
    w3 = np.array([w03,w13,w23,w33,w43,w53,w63,w73,w83,w93])

    b1 = np.array([b01,b11,b21,b31,b41,b51,b61,b71,b81,b91])
    b2 = np.array([b02,b12,b22,b32,b42,b52,b62,b72,b82,b92])
    b3 = np.array([b03,b13,b23,b33,b43,b53,b63,b73,b83,b93])

    W1 = w1.sum(axis=0)/10.0
    W2 = w2.sum(axis=0)/10.0
    W3 = w3.sum(axis=0)/10.0

    B1 = b1.sum(axis=0)/10.0
    B2 = b2.sum(axis=0)/10.0
    B3 = b3.sum(axis=0)/10.0

    model.set_weights([W1,B1,W2,B2,W3,B3])

#     y_predict = model.predict_classes(test.iloc[:,:-1])
#     Y_predict = np.array(test.digit)

#     print(classification_report(Y_predict, y_predict))


#     skplt.metrics.plot_roc_curve(Y_predict,model.predict(test.iloc[:,:-1]), figsize = (8,8))
#     plt.show()

    R.append(model.evaluate(test.iloc[:,:-1], test.digit))
    
    model.save('TEST-{}'.format(i))
    model.save('TEST')

    os.system('python3 client.py one 0')
    os.system('python3 client.py one 1')
    os.system('python3 client.py one 2')
    os.system('python3 client.py one 3')
    os.system('python3 client.py one 4')
    os.system('python3 client.py one 5')
    os.system('python3 client.py one 6')
    os.system('python3 client.py one 7')
    os.system('python3 client.py one 8')
    os.system('python3 client.py one 9')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))
# 110/110 [==============================] - 0s 910us/step - loss: 0.6450 - accuracy: 0.8696
# INFO:tensorflow:Assets written to: TEST-0/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 886us/step - loss: 0.5077 - accuracy: 0.8982
# INFO:tensorflow:Assets written to: TEST-1/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 875us/step - loss: 0.4996 - accuracy: 0.8959
# INFO:tensorflow:Assets written to: TEST-2/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 885us/step - loss: 0.4924 - accuracy: 0.8928
# INFO:tensorflow:Assets written to: TEST-3/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 1ms/step - loss: 0.4917 - accuracy: 0.8971
# INFO:tensorflow:Assets written to: TEST-4/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 881us/step - loss: 0.4983 - accuracy: 0.8917
# INFO:tensorflow:Assets written to: TEST-5/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 949us/step - loss: 0.4933 - accuracy: 0.8945
# INFO:tensorflow:Assets written to: TEST-6/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 918us/step - loss: 0.4878 - accuracy: 0.8985
# INFO:tensorflow:Assets written to: TEST-7/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 979us/step - loss: 0.4930 - accuracy: 0.8985
# INFO:tensorflow:Assets written to: TEST-8/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 940us/step - loss: 0.4816 - accuracy: 0.9005
# INFO:tensorflow:Assets written to: TEST-9/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 925us/step - loss: 0.4882 - accuracy: 0.9005
# INFO:tensorflow:Assets written to: TEST-10/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 920us/step - loss: 0.4886 - accuracy: 0.9005
# INFO:tensorflow:Assets written to: TEST-11/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 888us/step - loss: 0.4896 - accuracy: 0.9005
# INFO:tensorflow:Assets written to: TEST-12/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 942us/step - loss: 0.4974 - accuracy: 0.8988
# INFO:tensorflow:Assets written to: TEST-13/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 945us/step - loss: 0.4980 - accuracy: 0.9011
# INFO:tensorflow:Assets written to: TEST-14/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 922us/step - loss: 0.5059 - accuracy: 0.8948
# INFO:tensorflow:Assets written to: TEST-15/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 885us/step - loss: 0.4983 - accuracy: 0.9051
# INFO:tensorflow:Assets written to: TEST-16/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 999us/step - loss: 0.4928 - accuracy: 0.9074
# INFO:tensorflow:Assets written to: TEST-17/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 910us/step - loss: 0.4927 - accuracy: 0.9051
# INFO:tensorflow:Assets written to: TEST-18/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 921us/step - loss: 0.4944 - accuracy: 0.9057
# INFO:tensorflow:Assets written to: TEST-19/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 948us/step - loss: 0.4979 - accuracy: 0.9074
# INFO:tensorflow:Assets written to: TEST-20/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 882us/step - loss: 0.4992 - accuracy: 0.9054
# INFO:tensorflow:Assets written to: TEST-21/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 951us/step - loss: 0.5018 - accuracy: 0.9059
# INFO:tensorflow:Assets written to: TEST-22/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 1ms/step - loss: 0.5047 - accuracy: 0.9045
# INFO:tensorflow:Assets written to: TEST-23/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 891us/step - loss: 0.5047 - accuracy: 0.9059
# INFO:tensorflow:Assets written to: TEST-24/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 1ms/step - loss: 0.5021 - accuracy: 0.9079
# INFO:tensorflow:Assets written to: TEST-25/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 1ms/step - loss: 0.5020 - accuracy: 0.9097
# INFO:tensorflow:Assets written to: TEST-26/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 995us/step - loss: 0.5026 - accuracy: 0.9074
# INFO:tensorflow:Assets written to: TEST-27/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 935us/step - loss: 0.5338 - accuracy: 0.8934
# INFO:tensorflow:Assets written to: TEST-28/assets
# INFO:tensorflow:Assets written to: TEST/assets
# 110/110 [==============================] - 0s 990us/step - loss: 0.5017 - accuracy: 0.9071
# INFO:tensorflow:Assets written to: TEST-29/assets
# INFO:tensorflow:Assets written to: TEST/assets

# %%
import seaborn as sns
sns.set_theme(style= 'whitegrid')

plt.figure(figsize=(8,6))
plt.plot(list(map(lambda x:x[1],R)),label="accuracy")
plt.ylabel("accuracy")
plt.xlabel("round")
plt.legend(loc="lower right")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(list(map(lambda x:x[0],R)),label='loss')
plt.ylabel("loss")
plt.xlabel("round")
plt.legend()
plt.show()

# %%
import pickle
pickle.dump(R,open('cus1-FULL','wb'))

# %% [markdown]
# ### Plot

# %%
import pickle
cus1 = pickle.load(open('cus1-FULL','rb'))
cus2 = pickle.load(open('cus2-FULL','rb'))
cus3 = pickle.load(open('cus3-FULL','rb'))

# %%
plt.figure(figsize=(8,6))
plt.plot(list(map(lambda x:x[1],cus1[:25])),label='No Weighted')
plt.plot(list(map(lambda x:x[1],cus2)),label='Weighted')
plt.plot(list(map(lambda x:x[1],cus3)),label='Weighted2')
plt.ylabel("accuracy")
plt.xlabel("round")
plt.legend()
plt.show()

# %%
len(cus1)
# Out:
# 30

# %%
from scipy import interpolate
RANGE = range(1,26)
plt.figure(figsize=(8,6))
plt.plot(range(1,26),interpolate.UnivariateSpline(RANGE, list(map(lambda x:x[1],cus1[:-5])))(RANGE), label="No Weighted")
plt.plot(range(1,26),interpolate.UnivariateSpline(RANGE, list(map(lambda x:x[1],cus2)))(RANGE), label="Weighted")
plt.plot(range(1,26),interpolate.UnivariateSpline(RANGE, list(map(lambda x:x[1],cus3)))(RANGE), label="Weighted2")
plt.ylabel("accuracy")
plt.xlabel("round")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(list(map(lambda x:x[0],cus1)),label='default')
plt.plot(list(map(lambda x:x[0],cus2)),label='Weighted')
plt.plot(list(map(lambda x:x[0],cus3)),label='Weighted2')
plt.ylabel("loss")
plt.xlabel("round")
plt.legend()
plt.show()
